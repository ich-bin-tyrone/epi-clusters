# %%
import sys
import os

# 1. Get the path to the parent directory (project_root)
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# 2. Add the parent directory to Python's system path
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# 3. Import your functions
from src.preprocess_01 import print_hello

# %%
print_hello()
# Out:
# Hello, import successful!

# %%
import pandas as pd
import numpy as np

clinical_lihc_pd = pd.read_csv('../data/raw/TCGA-LIHC.clinical.tsv', sep='\t')
methylation_lihc_pd = pd.read_csv('../data/raw/TCGA-LIHC.methylation450.tsv', sep='\t')

# %%
methylation_lihc_pd.dtypes
# Out:
# Composite Element REF     object
# TCGA-DD-A73D-01A         float64
# TCGA-G3-A5SK-01A         float64
# TCGA-DD-A1EL-11A         float64
# TCGA-DD-AAD8-01A         float64
#                           ...
# TCGA-RC-A7S9-01A         float64
# TCGA-CC-A9FS-01A         float64
# TCGA-DD-AAEB-01A         float64
# TCGA-EP-A3RK-01A         float64
# TCGA-GJ-A3OU-01A         float64
# Length: 431, dtype: object
